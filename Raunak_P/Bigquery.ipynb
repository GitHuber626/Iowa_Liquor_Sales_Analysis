# %%
#Set environment variables for your notebook
import os 
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'bigqueryliquor.json'
#Imports google cloud client library and initiates BQ service
from google.cloud import bigquery
bigquery_client = bigquery.Client()
#Write Query on BQ
QUERY = """
SELECT * FROM `bigquery-public-data.iowa_liquor_sales.sales`

  """
#Run the query and write result to a pandas data frame
Query_Results = bigquery_client.query(QUERY)
df = Query_Results.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18944/1654237509.py in <module>
#      12 #Run the query and write result to a pandas data frame
#      13 Query_Results = bigquery_client.query(QUERY)
# ---> 14 df = Query_Results.to_dataframe()
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\job\query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object, max_results, geography_as_object)
#    1693         """
#    1694         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
# -> 1695         return query_result.to_dataframe(
#    1696             bqstorage_client=bqstorage_client,
#    1697             dtypes=dtypes,
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\table.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, date_as_object, geography_as_object)
#    1978             bqstorage_client = None
#    1979
# -> 1980         record_batch = self.to_arrow(
#    1981             progress_bar_type=progress_bar_type,
#    1982             bqstorage_client=bqstorage_client,
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\table.py in to_arrow(self, progress_bar_type, bqstorage_client, create_bqstorage_client)
#    1772
#    1773             record_batches = []
# -> 1774             for record_batch in self.to_arrow_iterable(
#    1775                 bqstorage_client=bqstorage_client
#    1776             ):
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\table.py in _to_page_iterable(self, bqstorage_download, tabledata_list_download, bqstorage_client)
#    1628             else tabledata_list_download()
#    1629         )
# -> 1630         yield from result_pages
#    1631
#    1632     def to_arrow_iterable(
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in download_arrow_row_iterator(pages, bq_schema)
#     626
#     627     for page in pages:
# --> 628         yield _row_iterator_page_to_arrow(page, column_names, arrow_types)
#     629
#     630
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\_pandas_helpers.py in _row_iterator_page_to_arrow(page, column_names, arrow_types)
#     599     arrays = []
#     600     for column_index, arrow_type in enumerate(arrow_types):
# --> 601         arrays.append(pyarrow.array(page._columns[column_index], type=arrow_type))
#     602
#     603     if isinstance(column_names, pyarrow.Schema):
#
# ~\anaconda3\lib\site-packages\pyarrow\array.pxi in pyarrow.lib.array()
#
# ~\anaconda3\lib\site-packages\pyarrow\array.pxi in pyarrow.lib._sequence_to_array()
#
# ~\anaconda3\lib\site-packages\pyarrow\error.pxi in pyarrow.lib.pyarrow_internal_check_status()
#
# ~\anaconda3\lib\site-packages\google\cloud\bigquery\table.py in get_column_data(field_index, field)
#    2693     def get_column_data(field_index, field):
#    2694         for row in rows:
# -> 2695             yield _helpers._field_from_json(row["f"][field_index]["v"], field)
#    2696
#    2697     for field_index, field in enumerate(schema):
#
# KeyboardInterrupt:

# %%
df
# Out:
#    invoice_and_item_number        date store_number  \
# 0             S15379100019  2013-10-28         3814
# 1          INV-23222900059  2019-11-13         2653
# 2          INV-03558800062  2017-03-02         2106
# 3          INV-13729100008  2018-08-08         4557
# 4          INV-06531900053  2017-08-08         3385
# ..                     ...         ...          ...
# 95            S21359000020  2014-09-23         4820
# 96            S31728300086  2016-04-11         4829
# 97         INV-28420500013  2020-07-01         5911
# 98         INV-23657400002  2019-12-04         2663
# 99            S22523700058  2014-11-21         2191
#
#                               store_name                  address  \
# 0                  Costco Wholesale #788    7205 MILLS CIVIC PKWY
# 1   Hy-Vee Wine and Spirits / Washington        1004 W Madison St
# 2            Hillstreet News and Tobacco             2217 College
# 3                 Hometown Foods / Traer            420 Second St
# 4         Sam's Club 8162 / Cedar Rapids  2605 Blairs Ferry Rd NE
# ..                                   ...                      ...
# 95                Lil' Chubs Corner Stop             712 S OAK ST
# 96                        Central City 2        1501 MICHIGAN AVE
# 97      Old Fire Liquor / Buffalo Center            113 1st St NW
# 98         Hy-Vee Food Store / Urbandale             8701 Douglas
# 99                        Keokuk Spirits                1013 MAIN
#
#                city zip_code                store_location county_number  \
# 0   WEST DES MOINES    50266  POINT (-93.806489 41.561342)            25
# 1        Washington  52353.0  POINT (-91.704567 41.296576)            92
# 2       Cedar Falls    50613  POINT (-92.455796 42.517182)             7
# 3             Traer    50675  POINT (-92.468086 42.193386)            86
# 4      Cedar Rapids  52402.0   POINT (-91.67969 42.031819)            57
# ..              ...      ...                           ...           ...
# 95           INWOOD    51240   POINT (-96.430827 43.30226)            60
# 96       DES MOINES    50314   POINT (-93.613739 41.60572)            77
# 97   Buffalo Center  50424.0  POINT (-93.947595 43.386755)            95
# 98        Urbandale  50322.0  POINT (-93.739105 41.629364)            77
# 99           KEOKUK    52632  POINT (-91.387797 40.400038)            56
#
#         county  ... item_number                item_description pack  \
# 0       Dallas  ...       28867                   Tanqueray Gin   12
# 1   WASHINGTON  ...       86251               Juarez Triple Sec   12
# 2   BLACK HAWK  ...       86251               Juarez Triple Sec   12
# 3         TAMA  ...       67527           Kahlua Coffee Liqueur   12
# 4         LINN  ...       86390            Montezuma Triple Sec   12
# ..         ...  ...         ...                             ...  ...
# 95        Lyon  ...       82600  Dekuyper Sour Apple Pucker Pet    6
# 96        Polk  ...       86251               Juarez Triple Sec   12
# 97   WINNEBAGO  ...       77055               Sir Winston Peach    6
# 98        POLK  ...       44266        British Navy Pussers Rum    6
# 99         Lee  ...       75087                 Juarez Gold Dss   12
#
#    bottle_volume_ml state_bottle_cost state_bottle_retail  bottles_sold  \
# 0              1000             14.99               22.48            72
# 1              1000              2.42                3.63             2
# 2              1000              2.42                3.63            72
# 3              1000             14.99               22.49             4
# 4              1000              2.13                3.20           132
# ..              ...               ...                 ...           ...
# 95             1750             11.54               17.31             3
# 96             1000              2.42                3.63           180
# 97              750             13.01               19.52            18
# 98              750             12.02               18.03            30
# 99             1000              4.92                7.38            96
#
#     sale_dollars  volume_sold_liters  volume_sold_gallons
# 0        1618.56               72.00                19.02
# 1           7.26                2.00                 0.52
# 2         261.36               72.00                19.02
# 3          89.96                4.00                 1.05
# 4         422.40              132.00                34.87
# ..           ...                 ...                  ...
# 95         51.93                5.25                 1.39
# 96        653.40              180.00                47.55
# 97        351.36               13.50                 3.56
# 98        540.90               22.50                 5.94
# 99        708.48               96.00                25.36
#
# [100 rows x 24 columns]
